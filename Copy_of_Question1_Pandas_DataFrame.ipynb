# %%
import pandas as pd

# Create student data
data = {
    "StudentID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Alice", "Bob", "Charlie", "Diana", "Ethan", "Fiona", "George", "Hannah", "Ivan", "Julia"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19, 22, 20],
    "Marks": [88, 75, 92, 65, 78, 85, 70, 95, 60, 80],
    "Grade": ["A", "B", "A", "C", "B", "A", "B", "A", "C", "B"]
}

df = pd.DataFrame(data)
df.to_csv("students.csv", index=False)
print("CSV file 'students.csv' created successfully.")
df_new = pd.read_csv("students.csv")
print("\nReloaded DataFrame:")
print("\nFirst 3 Rows:")
print(df_new.head(3))
print("\nStatistical Summary:")
print(df_new.describe())
print(df_new)
print("\nShape of DataFrame:")
print(df_new.shape)
print("Original DataFrame:")
print(df)
print("\nData Types:")
print(df_new.dtypes)
print("\nDataFrame Info:")
print(df_new.info())

# %%
import pandas as pd

# %% [markdown]
# imports the pandas library into your Python environment.

# %%
data = {
    "StudentID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Alice", "Bob", "Charlie", "Diana", "Ethan", "Fiona", "George", "Hannah", "Ivan", "Julia"],
    "Age": [20, 21, 19, 22, 20, 21, 23, 19, 22, 20],
    "Marks": [88, 75, 92, 65, 78, 85, 70, 95, 60, 80],
    "Grade": ["A", "B", "A", "C", "B", "A", "B", "A", "C", "B"]
}

# %% [markdown]
# This block defines a Python dictionary named data. Each key in this dictionary represents a column in what will later become a DataFrame.

# %%
df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
# 3        104    Diana   22     65     C
# 4        105    Ethan   20     78     B
# 5        106    Fiona   21     85     A
# 6        107   George   23     70     B
# 7        108   Hannah   19     95     A
# 8        109     Ivan   22     60     C
# 9        110    Julia   20     80     B

# %% [markdown]
#  It takes the data dictionary, which we discussed earlier, and converts it into a pandas DataFrame.
#  print original df :is a standard Python print statement.
#   This line of code, print(df), simply displays the entire content of the DataFrame named df to the output.

# %%
df.to_csv("students.csv", index=False)
print("CSV file 'students.csv' created successfully.")
# Out:
# CSV file 'students.csv' created successfully.

# %%
df_new = pd.read_csv("students.csv")
print("\nReloaded DataFrame:")
print(df_new)
# Out:
# Reloaded DataFrame:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A
# 3        104    Diana   22     65     C
# 4        105    Ethan   20     78     B
# 5        106    Fiona   21     85     A
# 6        107   George   23     70     B
# 7        108   Hannah   19     95     A
# 8        109     Ivan   22     60     C
# 9        110    Julia   20     80     B

# %% [markdown]
# student csv created. Saved dataframe as students.csv

# %% [markdown]
# Reload csv into new dataframe

# %%
print("\nFirst 3 Rows:")
print(df_new.head(3))
# Out:
# First 3 Rows:
#    StudentID     Name  Age  Marks Grade
# 0        101    Alice   20     88     A
# 1        102      Bob   21     75     B
# 2        103  Charlie   19     92     A

# %% [markdown]
# After reloading ,displaying only the first three rows.

# %%
print("\nStatistical Summary:")
print(df_new.describe())
# Out:
# Statistical Summary:
#        StudentID        Age      Marks
# count   10.00000  10.000000  10.000000
# mean   105.50000  20.700000  78.800000
# std      3.02765   1.337494  11.535453
# min    101.00000  19.000000  60.000000
# 25%    103.25000  20.000000  71.250000
# 50%    105.50000  20.500000  79.000000
# 75%    107.75000  21.750000  87.250000
# max    110.00000  23.000000  95.000000

# %% [markdown]
# Displays the statistical summary.

# %%
print("\nShape of DataFrame:")
print(df_new.shape)
# Out:
# Shape of DataFrame:
# (10, 5)

# %% [markdown]
# it displays the shape of the dataframe

# %%
print("\nData Types:")
print(df_new.dtypes)
# Out:
# Data Types:
# StudentID     int64
# Name         object
# Age           int64
# Marks         int64
# Grade        object
# dtype: object

# %% [markdown]
# prints what type of data type the df stores.

# %%
print("\nDataFrame Info:")
print(df_new.info())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  10 non-null     int64
#  1   Name       10 non-null     object
#  2   Age        10 non-null     int64
#  3   Marks      10 non-null     int64
#  4   Grade      10 non-null     object
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
# None

# %% [markdown]
# It displays  all the information and summary about the dataframe.
